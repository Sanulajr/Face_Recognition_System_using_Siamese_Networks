# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import cv2
import tensorflow as tf
from pathlib import Path
from tensorflow.keras import applications
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import optimizers
from tensorflow.keras import metrics
from tensorflow.keras import Model
from tensorflow.keras.applications import resnet
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
#Functions to generate image pairs
def generate_image_pairs(images, labels):
    # Generates index for each label
    unique_labels = np.unique(labels)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label, [index for index, curr_label in enumerate(labels) if label == curr_label])
    
    # Generates img pairs and labels them
    pair_images = []
    pair_labels = []
    for index, image in enumerate(images):
        pos_indices = label_wise_indices.get(labels[index])
        pos_image = images[np.random.choice(pos_indices)]
        pair_images.append((image, pos_image))
        pair_labels.append(1)

        neg_indices = np.where(labels != labels[index])
        # Func to generate image pairs
def generate_image_pairs(images, labels):
    # Generates an index for each label
    unique_labels = np.unique(labels)
    label_wise_indices = dict()
    for label in unique_labels:
        label_wise_indices.setdefault(label, [index for index, curr_label in enumerate(labels) if label == curr_label])
    
    # Create image pairs and labels them
    pair_images = []
    pair_labels = []
    for index, image in enumerate(images):
        pos_indices = label_wise_indices.get(labels[index])
        pos_image = images[np.random.choice(pos_indices)]
        pair_images.append((image, pos_image))
        pair_labels.append(1)

        neg_indices = np.where(labels != labels[index])

# %%
faces = 'olivetti_faces.npy'
faces_targets = 'olivetti_faces_target.npy'

# %%
face_images = np.load(faces)
face_labels = np.load(faces_targets)

# %%
target_shape = face_images[0].shape

# %%
images_dataset, labels_dataset = generate_image_pairs(face_images, face_labels)
images_dataset, labels_dataset = shuffle(images_dataset, labels_dataset)

# %%
def visualize(image_pairs, labels, n = 5, title = "Image Pair Examples"):
    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9)) 
    plt.title(title)
    axs = fig.subplots(n, 2)
    for i in range(n):
        show(axs[i, 0], image_pairs[i][0])
        show(axs[i, 1], image_pairs[i][1])

# %%
n = 5
indices = np.where(labels_dataset == 1)[:n]
visualize(images_dataset[indices], labels_dataset[indices], title = "Positive Image Examples")

# %%
n = 5
indices = np.where(labels_dataset == 0)[:n]
visualize(images_dataset[indices], labels_dataset[indices], title = "Negative Image Examples")

# %%
inputs = layers.Input((64, 64, 1))

x = layers.Conv2D(64, (10, 10), padding="same", activation="relu")(inputs)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (7, 7), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(128, (4, 4), padding="same", activation="relu")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)

x = layers.Conv2D(256, (4, 4), padding="same", activation="relu")(x)
fcOutput = layers.Flatten()(x)
fcOutput = layers.Dense(4096, activation = "relu")(fcOutput)
outputs = layers.Dense(1024, activation = "sigmoid")(fcOutput)

embedding = Model(inputs, outputs, name = "Embedding")

# %%
import tensorflow.keras.backend as K

# %%
def contrastive_loss(y, preds, margin=1):
    y = tf.cast(y, preds.dtype)
    squaredPreds = K.square(preds)
    squaredMargin = K.square(K.maximum(margin - preds, 0))
    loss = K.mean(y * squaredPreds + (1 - y) * squaredMargin)

    return loss

# %%
class DistanceLayer(layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, anchor, compare):
        sum_squared = K.sum(K.square(anchor - compare), axis=1, keepdims=True)
        return K.sqrt(K.maximum(sum_squared, K.epsilon()))

# %%
anchor_input = layers.Input(name="anchor", shape=target_shape + (1,))
compare_input = layers.Input(name="compare", shape=target_shape + (1,))

distances = DistanceLayer()(
    embedding(anchor_input),
    embedding(compare_input),
)

outputs = layers.Dense(1, activation = "sigmoid") (distances)

siamese_model = Model(
    inputs=[anchor_input, compare_input], outputs=outputs
)

# %%
siamese_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
history = siamese_model.fit([images_dataset[:, 0, :], images_dataset[:, 1, :]], labels_dataset,
                            epochs=150, validation_split = 0.2, batch_size = 64)
# Out:
# Epoch 1/150
# C:\Users\Sanula\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['anchor', 'compare']. Received: the structure of inputs=('*', '*')
#   warnings.warn(
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.5091 - loss: 0.6710 - val_accuracy: 0.5688 - val_loss: 0.6548
# Epoch 2/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.5073 - loss: 0.6203 - val_accuracy: 0.6187 - val_loss: 0.6585
# Epoch 3/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.5292 - loss: 0.6161 - val_accuracy: 0.6500 - val_loss: 0.6434
# Epoch 4/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5170 - loss: 0.6066 - val_accuracy: 0.6313 - val_loss: 0.6368
# Epoch 5/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.5086 - loss: 0.5987 - val_accuracy: 0.6125 - val_loss: 0.6361
# Epoch 6/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.
# Epoch 126/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9786 - loss: 0.1867 - val_accuracy: 0.8250 - val_loss: 0.5082
# Epoch 127/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9860 - loss: 0.1786 - val_accuracy: 0.8125 - val_loss: 0.5853
# Epoch 128/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9798 - loss: 0.1865 - val_accuracy: 0.8188 - val_loss: 0.5425
# Epoch 129/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9790 - loss: 0.1908 - val_accuracy: 0.8188 - val_loss: 0.5102
# Epoch 130/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9711 - loss: 0.2059 - val_accuracy: 0.6875 - val_loss: 0.6227
# Epoch 131/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.9399 - loss: 0.2512 - val_accuracy: 0.7750 - val_loss: 0.5098
# Epoch 132/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.8890 - loss: 0.3145 - val_accuracy: 0.8562 - val_loss: 0.4324
# Epoch 133/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9477 - loss: 0.2553 - val_accuracy: 0.8562 - val_loss: 0.4032
# Epoch 134/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.9611 - loss: 0.2181 - val_accuracy: 0.8188 - val_loss: 0.5077
# Epoch 135/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9576 - loss: 0.2131 - val_accuracy: 0.8313 - val_loss: 0.4197
# Epoch 136/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9749 - loss: 0.1977 - val_accuracy: 0.8438 - val_loss: 0.4671
# Epoch 137/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.9713 - loss: 0.1931 - val_accuracy: 0.8625 - val_loss: 0.4024
# Epoch 138/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9591 - loss: 0.2086 - val_accuracy: 0.8375 - val_loss: 0.4121
# Epoch 139/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9661 - loss: 0.1998 - val_accuracy: 0.8250 - val_loss: 0.4479
# Epoch 140/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.9737 - loss: 0.1909 - val_accuracy: 0.8375 - val_loss: 0.4136
# Epoch 141/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9719 - loss: 0.1943 - val_accuracy: 0.8687 - val_loss: 0.3670
# Epoch 142/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 27s 3s/step - accuracy: 0.9615 - loss: 0.2186 - val_accuracy: 0.8250 - val_loss: 0.4625
# Epoch 143/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 29s 3s/step - accuracy: 0.9653 - loss: 0.1936 - val_accuracy: 0.8562 - val_loss: 0.3877
# Epoch 144/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 30s 3s/step - accuracy: 0.9772 - loss: 0.1776 - val_accuracy: 0.8687 - val_loss: 0.3911
# Epoch 145/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9833 - loss: 0.1700 - val_accuracy: 0.8250 - val_loss: 0.4674
# Epoch 146/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.9812 - loss: 0.1652 - val_accuracy: 0.8250 - val_loss: 0.4582
# Epoch 147/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 34s 3s/step - accuracy: 0.9835 - loss: 0.1726 - val_accuracy: 0.8438 - val_loss: 0.4372
# Epoch 148/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.9813 - loss: 0.1742 - val_accuracy: 0.8313 - val_loss: 0.4461
# Epoch 149/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.9771 - loss: 0.1699 - val_accuracy: 0.8375 - val_loss: 0.4466
# Epoch 150/150
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 28s 3s/step - accuracy: 0.9804 - loss: 0.1683 - val_accuracy: 0.8625 - val_loss: 0.3898

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.legend(["Loss", "Validation Loss", "Accuracy", "Validation Accuracy"])

# %%
def test_visualize(images, n = 5):
    def show(ax, image):
        ax.imshow(image)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    fig = plt.figure(figsize=(9, 9)) 
    axs = fig.subplots(1, n)
    for i in range(n):
        show(axs[i], images[i])

# %%
test_indices = [0, 1, 2, 3, 4]
test_index = random.sample(range(10), 1)[0]
test_image = face_images[test_index]

compare_images = []
for i in range(5):
    index = random.sample(range(i * 10, (i + 1) * 10), 1)[0]
    image = face_images[index]
    compare_images.append(image)

# %%
plt.imshow(test_image)

# %%
test_visualize(compare_images)

# %%
image_pairs = []

for image in compare_images:
    image_pairs.append((test_image, image))
    
image_pairs = np.array(image_pairs)

# %%
score = siamese_model.predict([image_pairs[:, 0, :], image_pairs[:, 1, :]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
print(score)
# Out:
# [[7.9249775e-01]
#  [1.7147614e-01]
#  [4.9941835e-04]
#  [4.7906200e-04]
#  [1.1334551e-03]]

# %%
test_indices = [0, 1, 2, 3, 4]
test_index = random.sample(range(10, 20), 1)[0]
test_image = face_images[test_index]

compare_images = []
for i in range(5):
    index = random.sample(range(i * 10, (i + 1) * 10), 1)[0]
    image = face_images[index]
    compare_images.append(image)

# %%
plt.imshow(test_image)

# %%
test_visualize(compare_images)

# %%
image_pairs = []

for image in compare_images:
    image_pairs.append((test_image, image))
    
image_pairs = np.array(image_pairs)

# %%
score = siamese_model.predict([image_pairs[:, 0, :], image_pairs[:, 1, :]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step

# %%
print(score)
# Out:
# [[1.7130329e-01]
#  [7.6924288e-01]
#  [6.3228130e-04]
#  [8.0361747e-04]
#  [1.8040052e-03]]

# %%
from sklearn.metrics import accuracy_score, recall_score, f1_score

# %%
pred_scores = siamese_model.predict([images_dataset[:, 0, :], images_dataset[:, 1, :]])

threshold = 0.5
predicted_labels = (pred_scores > threshold).astype(int).flatten()

accuracy = accuracy_score(labels_dataset, predicted_labels)
recall = recall_score(labels_dataset, predicted_labels)
f1 = f1_score(labels_dataset, predicted_labels)

print(f"Accuracy: {accuracy}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 355ms/step
# Accuracy: 0.9475
# Recall: 0.945
# F1 Score: 0.9473684210526315
